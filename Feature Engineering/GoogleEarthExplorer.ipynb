# %% [markdown]
# # Extracting MODIS and Landsat-8 Data Using Google Earth Engine

# %%
import ee
import pandas as pd
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=fRDCDgOhG1ymPh-RK8gKwUZdfb2kGg39v1Xq7XnnC9o&tc=VNEkht7HB6Z7PAXvMLcdbfI9UXVs-8w6NL1bbIVrYNc&cc=ghD9jItowGvj4MJOsTnO-pDZDHsEFdn8hPkPMb2TAi0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=fRDCDgOhG1ymPh-RK8gKwUZdfb2kGg39v1Xq7XnnC9o&tc=VNEkht7HB6Z7PAXvMLcdbfI9UXVs-8w6NL1bbIVrYNc&cc=ghD9jItowGvj4MJOsTnO-pDZDHsEFdn8hPkPMb2TAi0</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %% [markdown]
# ### Accessing the MODIS chlor_a data for the Bahamas and adding it to the modis_caribbean datafrane

# %%
# accessing modis data from ee
chlor_a = ee.ImageCollection("NASA/OCEANDATA/MODIS-Aqua/L3SMI").select("chlor_a")

# %%
years = ['2018', '2019', '2020', '2021']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

modis_car = pd.DataFrame()

for year in years:
    for month in range(len(months)-1):
        start_date = f'{year}-{months[month]}-01'
        end_date = f'{year}-{months[month+1]}-01'
        print(f'extracting data for {start_date} to {end_date}')
        
        try:
            curr_image = chlor_a.filterBounds(geometry=ee.Geometry.Rectangle([[-85, 17],[-63, 27]])).filterDate(start_date, end_date)
            curr_data = curr_image.getRegion(geometry=ee.Geometry.Rectangle([[-85, 17],[-63, 27]]), scale=10000).getInfo()
            curr_df = pd.DataFrame(curr_data[1:], columns=curr_data[0])[['longitude', 'latitude', 'time', 'chlor_a']]
            curr_df = curr_df.dropna()
            modis_car = pd.concat([modis_car, curr_df])
        except:
            continue
            
        print(f'current size = {modis_car.shape}')
# Out:
# extracting data for 2018-01-01 to 2018-02-01
# current size = (145189, 4)
# extracting data for 2018-02-01 to 2018-03-01
# current size = (416755, 4)
# extracting data for 2018-03-01 to 2018-04-01
# current size = (634694, 4)
# extracting data for 2018-04-01 to 2018-05-01
# current size = (825860, 4)
# extracting data for 2018-05-01 to 2018-06-01
# current size = (903921, 4)
# extracting data for 2018-06-01 to 2018-07-01
# current size = (1011669, 4)
# extracting data for 2018-07-01 to 2018-08-01
# current size = (1099642, 4)
# extracting data for 2018-08-01 to 2018-09-01
# current size = (1255494, 4)
# extracting data for 2018-09-01 to 2018-10-01
# current size = (1424377, 4)
# extracting data for 2018-10-01 to 2018-11-01
# current size = (1658340, 4)
# extracting data for 2018-11-01 to 2018-12-01
# current size = (1917987, 4)
# extracting data for 2019-01-01 to 2019-02-01
# current size = (2193725, 4)
# extracting data for 2019-02-01 to 2019-03-01
# current size = (2469957, 4)
# extracting data for 2019-03-01 to 2019-04-01
# current size = (2700471, 4)
# extracting data for 2019-04-01 to 2019-05-01
# current size = (2878956, 4)
# extracting data for 2019-05-01 to 2019-06-01
# current size = (3016954, 4)
# extracting data for 2019-06-01 to 2019-07-01
# current size = (3173048, 4)
# extracting data for 2019-07-01 to 2019-08-01
# current size = (3336564, 4)
# extracting data for 2019-08-01 to 2019-09-01
# current size = (3472859, 4)
# extracting data for 2019-09-01 to 2019-10-01
# current size = (3606757, 4)
# extracting data for 2019-10-01 to 2019-11-01
# current size = (3830299, 4)
# extracting data for 2019-11-01 to 2019-12-01
# current size = (4088734, 4)
# extracting data for 2020-01-01 to 2020-02-01
# current size = (4349294, 4)
# extracting data for 2020-02-01 to 2020-03-01
# current size = (4607144, 4)
# extracting data for 2020-03-01 to 2020-04-01
# current size = (4831865, 4)
# extracting data for 2020-04-01 to 2020-05-01
# current size = (5026955, 4)
# extracting data for 2020-05-01 to 2020-06-01
# current size = (5135252, 4)
# extracting data for 2020-06-01 to 2020-07-01
# current size = (5256243, 4)
# extracting data for 2020-07-01 to 2020-08-01
# current size = (5373632, 4)
# extracting data for 2020-08-01 to 2020-09-01
# current size = (5531139, 4)
# extracting data for 2020-09-01 to 2020-10-01
# current size = (5691111, 4)
# extracting data for 2020-10-01 to 2020-11-01
# current size = (5876843, 4)
# extracting data for 2020-11-01 to 2020-12-01
# current size = (6033336, 4)
# extracting data for 2021-01-01 to 2021-02-01
# current size = (6283777, 4)
# extracting data for 2021-02-01 to 2021-03-01
# current size = (6558422, 4)
# extracting data for 2021-03-01 to 2021-04-01
# current size = (6800318, 4)
# extracting data for 2021-04-01 to 2021-05-01
# current size = (6964998, 4)
# extracting data for 2021-05-01 to 2021-06-01
# current size = (7141356, 4)
# extracting data for 2021-06-01 to 2021-07-01
# current size = (7237251, 4)
# extracting data for 2021-07-01 to 2021-08-01
# extracting data for 2021-08-01 to 2021-09-01
# current size = (7256617, 4)
# extracting data for 2021-09-01 to 2021-10-01
# current size = (7445738, 4)
# extracting data for 2021-10-01 to 2021-11-01
# current size = (7629568, 4)
# extracting data for 2021-11-01 to 2021-12-01

# %%
# modis_car.to_pickle('./files/MODIS/modis_car.pkl')

# %% [markdown]
# ### Extracting chlor_a data for the Great Barrier Reef and adding it to modis_gb dataframe

# %%
chlor_a = ee.ImageCollection("NASA/OCEANDATA/MODIS-Aqua/L3SMI").select("chlor_a")

# %%
years = ['2018', '2019', '2020', '2021']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

modis_gb = pd.DataFrame()

for year in years:
    for month in range(len(months)-1):
        start_date = f'{year}-{months[month]}-01'
        end_date = f'{year}-{months[month+1]}-01'
        print(f'extracting data for {start_date} to {end_date}')
        
        try:
            curr_image = chlor_a.filterBounds(geometry=ee.Geometry.Rectangle([[142.69 , -10],[153.7, -28.7]])).filterDate(start_date, end_date)
            curr_data = curr_image.getRegion(geometry=ee.Geometry.Rectangle([[142.69 , -10],[153.7, -28.7]]), scale=100).getInfo()
            curr_df = pd.DataFrame(curr_data[1:], columns=curr_data[0])[['longitude', 'latitude', 'time', 'chlor_a']]
            curr_df = curr_df.dropna()
            modis_gb = pd.concat([modis_gb, curr_df])
        except:
            continue
            
        print(f'current size = {modis_gb.shape}')
# Out:
# extracting data for 2018-01-01 to 2018-02-01
# extracting data for 2018-02-01 to 2018-03-01
# extracting data for 2018-03-01 to 2018-04-01
# extracting data for 2018-04-01 to 2018-05-01
# extracting data for 2018-05-01 to 2018-06-01
# extracting data for 2018-06-01 to 2018-07-01
# extracting data for 2018-07-01 to 2018-08-01
# extracting data for 2018-08-01 to 2018-09-01
# extracting data for 2018-09-01 to 2018-10-01
# extracting data for 2018-10-01 to 2018-11-01
# extracting data for 2018-11-01 to 2018-12-01
# extracting data for 2019-01-01 to 2019-02-01
# extracting data for 2019-02-01 to 2019-03-01
# extracting data for 2019-03-01 to 2019-04-01
# extracting data for 2019-04-01 to 2019-05-01
# extracting data for 2019-05-01 to 2019-06-01
# extracting data for 2019-06-01 to 2019-07-01
# extracting data for 2019-07-01 to 2019-08-01
# extracting data for 2019-08-01 to 2019-09-01
# extracting data for 2019-09-01 to 2019-10-01
# extracting data for 2019-10-01 to 2019-11-01
# extracting data for 2019-11-01 to 2019-12-01
# extracting data for 2020-01-01 to 2020-02-01
# extracting data for 2020-02-01 to 2020-03-01
# extracting data for 2020-03-01 to 2020-04-01
# extracting data for 2020-04-01 to 2020-05-01
# extracting data for 2020-05-01 to 2020-06-01
# extracting data for 2020-06-01 to 2020-07-01
# extracting data for 2020-07-01 to 2020-08-01
# extracting data for 2020-08-01 to 2020-09-01
# extracting data for 2020-09-01 to 2020-10-01
# extracting data for 2020-10-01 to 2020-11-01
# extracting data for 2020-11-01 to 2020-12-01
# extracting data for 2021-01-01 to 2021-02-01
# extracting data for 2021-02-01 to 2021-03-01
# extracting data for 2021-03-01 to 2021-04-01
# extracting data for 2021-04-01 to 2021-05-01
# extracting data for 2021-05-01 to 2021-06-01
# extracting data for 2021-06-01 to 2021-07-01
# extracting data for 2021-07-01 to 2021-08-01
# extracting data for 2021-08-01 to 2021-09-01
# extracting data for 2021-09-01 to 2021-10-01
# extracting data for 2021-10-01 to 2021-11-01
# extracting data for 2021-11-01 to 2021-12-01

# %%
# modis_gb.to_pickle('./files/MODIS/modis_gb.pkl')

# %% [markdown]
# ### Extracting MODIS Reflectance Values for Great Barrier Reef from Earth Engine

# %%
from ee import EEException

bands = ['sur_refl_b09', 'sur_refl_b10', 'sur_refl_b11', 'sur_refl_b12', 'sur_refl_b12', 'sur_refl_b13', 'sur_refl_b14', 'sur_refl_b15', 'sur_refl_b16']
years = ['2018', '2019', '2020', '2021']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

for band in bands:
    print(f'Extracting {band} data')
    modis_gb = pd.DataFrame()
    img = ee.ImageCollection("MODIS/006/MYDOCGA").select(band)
    for year in years:
        for month in range(len(months)-1):
            start_date = f'{year}-{months[month]}-01'
            end_date = f'{year}-{months[month+1]}-01'
            print(f'extracting {band} data for {start_date} to {end_date}')
            
            try:
                curr_image = img.filterBounds(geometry=ee.Geometry.Rectangle([[142.69 , -10],[153.7, -28.7]])).filterDate(start_date, end_date)
                curr_data = curr_image.getRegion(geometry=ee.Geometry.Rectangle([[142.69 , -10],[153.7, -28.7]]), scale=10000).getInfo()
                curr_df = pd.DataFrame(curr_data[1:], columns=curr_data[0])[['longitude', 'latitude', 'time', band]]
                curr_df = curr_df.dropna()
                modis_gb = pd.concat([modis_gb, curr_df])
            except EEException:
                continue
    modis_gb.to_pickle(f'./files/MODIS/modis_gb_{band}.pkl')
    print(f'Saved {band} data to pickle file')
# Out:
# Extracting sur_refl_b09 data
# extracting sur_refl_b09 data for 2018-01-01 to 2018-02-01
# extracting sur_refl_
data for 2018-11-01 to 2018-12-01
# extracting sur_refl_b15 data for 2019-01-01 to 2019-02-01
# extracting sur_refl_b15 data for 2019-02-01 to 2019-03-01
# extracting sur_refl_b15 data for 2019-03-01 to 2019-04-01
# extracting sur_refl_b15 data for 2019-04-01 to 2019-05-01
# extracting sur_refl_b15 data for 2019-05-01 to 2019-06-01
# extracting sur_refl_b15 data for 2019-06-01 to 2019-07-01
# extracting sur_refl_b15 data for 2019-07-01 to 2019-08-01
# extracting sur_refl_b15 data for 2019-08-01 to 2019-09-01
# extracting sur_refl_b15 data for 2019-09-01 to 2019-10-01
# extracting sur_refl_b15 data for 2019-10-01 to 2019-11-01
# extracting sur_refl_b15 data for 2019-11-01 to 2019-12-01
# extracting sur_refl_b15 data for 2020-01-01 to 2020-02-01
# extracting sur_refl_b15 data for 2020-02-01 to 2020-03-01
# extracting sur_refl_b15 data for 2020-03-01 to 2020-04-01
# extracting sur_refl_b15 data for 2020-04-01 to 2020-05-01
# extracting sur_refl_b15 data for 2020-05-01 to 2020-06-01
# extracting sur_refl_b15 data for 2020-06-01 to 2020-07-01
# extracting sur_refl_b15 data for 2020-07-01 to 2020-08-01
# extracting sur_refl_b15 data for 2020-08-01 to 2020-09-01
# extracting sur_refl_b15 data for 2020-09-01 to 2020-10-01
# extracting sur_refl_b15 data for 2020-10-01 to 2020-11-01
# extracting sur_refl_b15 data for 2020-11-01 to 2020-12-01
# extracting sur_refl_b15 data for 2021-01-01 to 2021-02-01
# extracting sur_refl_b15 data for 2021-02-01 to 2021-03-01
# extracting sur_refl_b15 data for 2021-03-01 to 2021-04-01
# extracting sur_refl_b15 data for 2021-04-01 to 2021-05-01
# extracting sur_refl_b15 data for 2021-05-01 to 2021-06-01
# extracting sur_refl_b15 data for 2021-06-01 to 2021-07-01
# extracting sur_refl_b15 data for 2021-07-01 to 2021-08-01
# extracting sur_refl_b15 data for 2021-08-01 to 2021-09-01
# extracting sur_refl_b15 data for 2021-09-01 to 2021-10-01
# extracting sur_refl_b15 data for 2021-10-01 to 2021-11-01
# extracting sur_refl_b15 data for 2021-11-01 to 2021-12-01
# Saved sur_refl_b15 data to pickle file
# Extracting sur_refl_b16 data
# extracting sur_refl_b16 data for 2018-01-01 to 2018-02-01
# extracting sur_refl_b16 data for 2018-02-01 to 2018-03-01
# extracting sur_refl_b16 data for 2018-03-01 to 2018-04-01
# extracting sur_refl_b16 data for 2018-04-01 to 2018-05-01
# extracting sur_refl_b16 data for 2018-05-01 to 2018-06-01
# extracting sur_refl_b16 data for 2018-06-01 to 2018-07-01
# extracting sur_refl_b16 data for 2018-07-01 to 2018-08-01
# extracting sur_refl_b16 data for 2018-08-01 to 2018-09-01
# extracting sur_refl_b16 data for 2018-09-01 to 2018-10-01
# extracting sur_refl_b16 data for 2018-10-01 to 2018-11-01
# extracting sur_refl_b16 data for 2018-11-01 to 2018-12-01
# extracting sur_refl_b16 data for 2019-01-01 to 2019-02-01
# extracting sur_refl_b16 data for 2019-02-01 to 2019-03-01
# extracting sur_refl_b16 data for 2019-03-01 to 2019-04-01
# extracting sur_refl_b16 data for 2019-04-01 to 2019-05-01
# extracting sur_refl_b16 data for 2019-05-01 to 2019-06-01
# extracting sur_refl_b16 data for 2019-06-01 to 2019-07-01
# extracting sur_refl_b16 data for 2019-07-01 to 2019-08-01
# extracting sur_refl_b16 data for 2019-08-01 to 2019-09-01
# extracting sur_refl_b16 data for 2019-09-01 to 2019-10-01
# extracting sur_refl_b16 data for 2019-10-01 to 2019-11-01
# extracting sur_refl_b16 data for 2019-11-01 to 2019-12-01
# extracting sur_refl_b16 data for 2020-01-01 to 2020-02-01
# extracting sur_refl_b16 data for 2020-02-01 to 2020-03-01
# extracting sur_refl_b16 data for 2020-03-01 to 2020-04-01
# extracting sur_refl_b16 data for 2020-04-01 to 2020-05-01
# extracting sur_refl_b16 data for 2020-05-01 to 2020-06-01
# extracting sur_refl_b16 data for 2020-06-01 to 2020-07-01
# extracting sur_refl_b16 data for 2020-07-01 to 2020-08-01
# extracting sur_refl_b16 data for 2020-08-01 to 2020-09-01
# extracting sur_refl_b16 data for 2020-09-01 to 2020-10-01
# extracting sur_refl_b16 data for 2020-10-01 to 2020-11-01
# extracting sur_refl_b16 data for 2020-11-01 to 2020-12-01
# extracting sur_refl_b16 data for 2021-01-01 to 2021-02-01
# extracting sur_refl_b16 data for 2021-02-01 to 2021-03-01
# extracting sur_refl_b16 data for 2021-03-01 to 2021-04-01
# extracting sur_refl_b16 data for 2021-04-01 to 2021-05-01
# extracting sur_refl_b16 data for 2021-05-01 to 2021-06-01
# extracting sur_refl_b16 data for 2021-06-01 to 2021-07-01
# extracting sur_refl_b16 data for 2021-07-01 to 2021-08-01
# extracting sur_refl_b16 data for 2021-08-01 to 2021-09-01
# extracting sur_refl_b16 data for 2021-09-01 to 2021-10-01
# extracting sur_refl_b16 data for 2021-10-01 to 2021-11-01
# extracting sur_refl_b16 data for 2021-11-01 to 2021-12-01
# Saved sur_refl_b16 data to pickle file

# %%
bands = ['sur_refl_b08', 'sur_refl_b09', 'sur_refl_b10', 'sur_refl_b11', 'sur_refl_b12', 'sur_refl_b12', 'sur_refl_b13', 'sur_refl_b14', 'sur_refl_b15', 'sur_refl_b16']
years = ['2018', '2019', '2020', '2021']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

for band in bands:
    img = ee.ImageCollection("MODIS/006/MYDOCGA").select(band)
    print(f'Extracting {band} data')
    modis_car = pd.DataFrame()
    for year in years:
        for month in range(len(months)-1):
            start_date = f'{year}-{months[month]}-01'
            end_date = f'{year}-{months[month+1]}-01'
            print(f'extracting {band} data for {start_date} to {end_date}')
            
            try:
                curr_image = img.filterBounds(geometry=ee.Geometry.Rectangle([[-85, 17],[-63, 27]])).filterDate(start_date, end_date)
                curr_data = curr_image.getRegion(geometry=ee.Geometry.Rectangle([[-85, 17],[-63, 27]]), scale=10000).getInfo()
                curr_df = pd.DataFrame(curr_data[1:], columns=curr_data[0])[['longitude', 'latitude', 'time', f'{band}']]
                curr_df = curr_df.dropna()
                modis_car = pd.concat([modis_car, curr_df])
            except:
                continue
    modis_car.to_pickle(f'./files/MODIS/modis_car_{band}.pkl')
    print(f'Saved {band} data to pickle file')
# Out:
# Extracting sur_refl_b08 data
# extracting sur_refl_b08 data for 2018-01-01 to 2018-02-01
# extracting sur_refl_b08 data for 2018-02-01 to 2018-03-01
# extracting sur_refl_b08 data for 2018-03-01 to 2018-04-01
# extracting sur_refl_b08 data for 2018-04-01 to 2018-05-01
# extracting sur_refl_b08 data for 2018-05-01 to 2018-06-01
# extracting sur_refl_b08 data for 2018-06-01 to 2018-07-01
# extracting sur_refl_b08 data for 2018-07-01 to 2018-08-01
# extracting sur_refl_b08 data for 2018-08-01 to 2018-09-01
# extracting sur_refl_b08 data for 2018-09-01 to 2018-10-01
# extracting sur_refl_b08 data for 2018-10-01 to 2018-11-01
# extracting sur_refl_b08 data for 2018-11-01 to 2018-12-01
# extracting sur_refl_b08 data for 2019-01-01 to 2019-02-01
# extracting sur_refl_b08 data for 2019-02-01 to 2019-03-01
# extracting sur_refl_b08 data for 2019-03-01 to 2019-04-01
# extracting sur_refl_b08 data for 2019-04-01 to 2019-05-01
# extracting sur_refl_b08 data for 2019-05-01 to 2019-06-01
# extracting sur_refl_b08 data for 2019-06-01 to 2019-07-01
# extracting sur_refl_b08 data for 2019-07-01 to 2019-08-01
# extracting sur_refl_b08 data for 2019-08-01 to 2019-09-01
# extracting sur_refl_b08 data for 2019-09-01 to 2019-10-01
# extracting sur_refl_b08 data for 2019-10-01 to 2019-11-01
# extracting sur_refl_b08 data for 2019-11-01 to 2019-12-01
# extracting sur_refl_b08 data for 2020-01-01 to 2020-02-01
# extracting sur_refl_b08 data for 2020-02-01 to 2020-03-01
# extracting sur_refl_b08 data for 2020-03-01 to 2020-04-01
# extracting sur_refl_b08 data for 2020-04-01 to 2020-05-01
# extracting sur_refl_b08 data for 2020-05-01 to 2020-06-01
# extracting sur_refl_b08 data for 2020-06-01 to 2020-07-01
# extracting sur_refl_b08 data for 2020-07-01 to 2020-08-01
# extracting sur_refl_b08 data for 2020-08-01 to 2020-09-01
# extracting sur_refl_b08 data for 2020-09-01 to 2020-10-01
# extracting sur_refl_b08 data for 2020-10-01 to 2020-11-01
# extracting sur_refl_b08 data for 2020-11-01 to 2020-12-01
# extracting sur_refl_b08 data for 2021-01-01 to 2021-02-01
# extracting sur_refl_b08 data for 2021-02-01 to 2021-03-01
# extracting sur_refl_b08 data for 2021-03-01 to 2021-04-01
# extracting sur_refl_b08 data for 2021-04-01 to 2021-05-01
# extracting sur_refl_b08 data for 2021-05-01 to 2021-06-01
# extracting sur_refl_b08 data for 2021-06-01 to 2021-07-01
# extracting sur_refl_b08 data for 2021-07-01 to 2021-08-01
# extracting sur_refl_b08 data for 2021-08-01 to 2021-09-01
# extracting sur_refl_b08 data for 2021-09-01 to 2021-10-01
# extracting sur_refl_b08 data for 2021-10-01 to 2021-11-01
# extracting sur_refl_b08 data for 2021-11-01 to 2021-12-01
# Saved sur_refl_b08 data to pickle file
# Extracting sur_refl_b09 data
# extracting sur_refl_b09 data for 2018-01-01 to 2018-02-01
# extracting sur_refl_b09 data for 2018-02-01 to 2018-03-01
# extracting sur_refl_b09 data for 2018-03-01 to 2018-04-01
# extracting sur_refl_b09 data for 2018-04-01 to 2018-05-01
# extracting sur_refl_b09 data for 2018-05-01 to 2018-06-01
# extracting sur_refl_b09 data for 2018-06-01 to 2018-07-01
# extracting sur_refl_b09 data for 2018-07-01 to 2018-08-01
# extracting sur_refl_b09 data for 2018-08-01 to 2018-09-01
# extracting sur_refl_b09 data for 2018-09-01 to 2018-10-01
# extracting sur_refl_b09 data for 2018-10-01 to 2018-11-01
# extracting sur_refl_b09 data for 2018-11-01 to 2018-12-01
# extracting sur_refl_b09 data for 2019-01-01 to 2019-02-01
# extracting sur_refl_b09 data for 2019-02-01 to 2019-03-01
# extracting sur_refl_b09 data for 2019-03-01 to 2019-04-01
# extracting sur_refl_b09 data for 2019-04-01 to 2019-05-01
# extracting sur_refl_b09 data for 2019-05-01 to 2019-06-01
# extracting sur_refl_b09 data for 2019-06-01 to 2019-07-01
# extracting sur_refl_b09 data for 2019-07-01 to 2019-08-01
# extracting sur_refl_b09 data for 2019-08-01 to 2019-09-01
# extracting sur_refl_b09 data for 2019-09-01 to 2019-10-01
# extracting sur_refl_b09 data for 2019-10-01 to 2019-11-01
# extracting sur_refl_b09 data for 2019-11-01 to 2019-12-01
# extracting sur_refl_b09 data for 2020-01-01 to 2020-02-01
# extracting sur_refl_b09 data for 2020-02-01 to 2020-03-01
# extracting sur_refl_b09 data for 2020-03-01 to 2020-04-01
# extracting sur_refl_b09 data for 2020-04-01 to 2020-05-01
# extracting sur_refl_b09 data for 2020-05-01 to 2020-06-01
# extracting sur_refl_b09 data for 2020-06-01 to 2020-07-01
# extracting sur_refl_b09 data for 2020-07-01 to 2020-08-01
# extracting sur_refl_b09 data for 2020-08-01 to 2020-09-01
# extracting sur_refl_b09 data for 2020-09-01 to 2020-10-01
# extracting sur_refl_b09 data for 2020-10-01 to 2020-11-01
# extracting sur_refl_b09 data for 2020-11-01 to 2020-12-01
# extracting sur_refl_b09 data for 2021-01-01 to 2021-02-01
# extracting sur_refl_b09 data for 2021-02-01 to 2021-03-01
# extracting sur_refl_b09 data for 2021-03-01 to 2021-04-01
# extracting sur_refl_b09 data for 2021-04-01 to 2021-05-01
# extracting sur_refl_b09 data for 2021-05-01 to 2021-06-01
# extracting sur_refl_b09 data for 2021-06-01 to 2021-07-01
# extracting sur_refl_b09 data for 2021-07-01 to 2021-08-01
# extracting sur_refl_b09 data for 2021-08-01 to 2021-09-01
# extracting sur_refl_b09 data for 2021-09-01 to 2021-10-01
# extracting sur_refl_b09 data for 2021-10-01 to 2021-11-01
# extracting sur_refl_b09 data for 2021-11-01 to 2021-12-01
# Saved sur_refl_b09 data to pickle file
# Extracting sur_refl_b10 data
# extracting sur_refl_b10 data for 2018-01-01 to 2018-02-01
# extracting sur_refl_b10 data for 2018-02-01 to 2018-03-01
# extracting sur_refl_b10 data for 2018-03-01 to 2018-04-01
# extracting sur_refl_b10 data for 2018-04-01 to 2018-05-01
# extracting sur_refl_b10 data for 2018-05-01 to 2018-06-01
# extracting sur_refl_b10 data for 2018-06-01 to 2018-07-01
# extracting sur_refl_b10 data for 2018-07-01 to 2018-08-01
# extracting sur_refl_b10 data for 2018-08-01 to 2018-09-01
# extracting sur_refl_b10 data for 2018-09-01 to 2018-10-01
# extracting sur_refl_b10 data for 2018-10-01 to 2018-11-01
# extracting sur_refl_b10 data for 2018-11-01 to 2018-12-01
# extracting sur_refl_b10 data for 2019-01-01 to 2019-02-01
# extracting sur_refl_b10 data for 2019-02-01 to 2019-03-01
# extracting sur_refl_b10 data for 2019-03-01 to 2019-04-01
# extracting sur_refl_b10 data for 2019-04-01 to 2019-05-01
# extracting sur_refl_b10 data for 2019-05-01 to 2019-06-01
# extracting sur_refl_b10 data for 2019-06-01 to 2019-07-01
# extracting sur_refl_b10 data for 2019-07-01 to 2019-08-01
# extracting sur_refl_b10 data for 2019-08-01 to 2019-09-01
# extracting sur_refl_b10 data for 2019-09-01 to 2019-10-01
# extracting sur_refl_b10 data for 2019-10-01 to 2019-11-01
# extracting sur_refl_b10 data for 2019-11-01 to 2019-12-01
# extracting sur_refl_b10 data for 2020-01-01 to 2020-02-01
# extracting sur_refl_b10 data for 2020-02-01 to 2020-03-01
# extracting sur_refl_b10 data for 2020-03-01 to 2020-04-01
# extracting sur_refl_b10 data for 2020-04-01 to 2020-05-01
# extracting sur_refl_b10 data for 2020-05-01 to 2020-06-01
# extracting sur_refl_b10 data for 2020-06-01 to 2020-07-01
# extracting sur_refl_b10 data for 2020-07-01 to 2020-08-01
# extracting sur_refl_b10 data for 2020-08-01 to 2020-09-01
# extracting sur_refl_b10 data for 2020-09-01 to 2020-10-01
# extracting sur_refl_b10 data for 2020-10-01 to 2020-11-01
# extracting sur_refl_b10 data for 2020-11-01 to 2020-12-01
# extracting sur_refl_b10 data for 2021-01-01 to 2021-02-01
# extracting sur_refl_b10 data for 2021-02-01 to 2021-03-01
# extracting sur_refl_b10 data for 2021-03-01 to 2021-04-01
# extracting sur_refl_b10 data for 2021-04-01 to 2021-05-01
# extracting sur_refl_b10 data for 2021-05-01 to 2021-06-01
# extracting sur_refl_b10 data for 2021-06-01 to 2021-07-01
# extracting sur_refl_
# extracting sur_refl_b16 data for 2018-08-01 to 2018-09-01
# extracting sur_refl_b16 data for 2018-09-01 to 2018-10-01
# extracting sur_refl_b16 data for 2018-10-01 to 2018-11-01
# extracting sur_refl_b16 data for 2018-11-01 to 2018-12-01
# extracting sur_refl_b16 data for 2019-01-01 to 2019-02-01
# extracting sur_refl_b16 data for 2019-02-01 to 2019-03-01
# extracting sur_refl_b16 data for 2019-03-01 to 2019-04-01
# extracting sur_refl_b16 data for 2019-04-01 to 2019-05-01
# extracting sur_refl_b16 data for 2019-05-01 to 2019-06-01
# extracting sur_refl_b16 data for 2019-06-01 to 2019-07-01
# extracting sur_refl_b16 data for 2019-07-01 to 2019-08-01
# extracting sur_refl_b16 data for 2019-08-01 to 2019-09-01
# extracting sur_refl_b16 data for 2019-09-01 to 2019-10-01
# extracting sur_refl_b16 data for 2019-10-01 to 2019-11-01
# extracting sur_refl_b16 data for 2019-11-01 to 2019-12-01
# extracting sur_refl_b16 data for 2020-01-01 to 2020-02-01
# extracting sur_refl_b16 data for 2020-02-01 to 2020-03-01
# extracting sur_refl_b16 data for 2020-03-01 to 2020-04-01
# extracting sur_refl_b16 data for 2020-04-01 to 2020-05-01
# extracting sur_refl_b16 data for 2020-05-01 to 2020-06-01
# extracting sur_refl_b16 data for 2020-06-01 to 2020-07-01
# extracting sur_refl_b16 data for 2020-07-01 to 2020-08-01
# extracting sur_refl_b16 data for 2020-08-01 to 2020-09-01
# extracting sur_refl_b16 data for 2020-09-01 to 2020-10-01
# extracting sur_refl_b16 data for 2020-10-01 to 2020-11-01
# extracting sur_refl_b16 data for 2020-11-01 to 2020-12-01
# extracting sur_refl_b16 data for 2021-01-01 to 2021-02-01
# extracting sur_refl_b16 data for 2021-02-01 to 2021-03-01
# extracting sur_refl_b16 data for 2021-03-01 to 2021-04-01
# extracting sur_refl_b16 data for 2021-04-01 to 2021-05-01
# extracting sur_refl_b16 data for 2021-05-01 to 2021-06-01
# extracting sur_refl_b16 data for 2021-06-01 to 2021-07-01
# extracting sur_refl_b16 data for 2021-07-01 to 2021-08-01
# extracting sur_refl_b16 data for 2021-08-01 to 2021-09-01
# extracting sur_refl_b16 data for 2021-09-01 to 2021-10-01
# extracting sur_refl_b16 data for 2021-10-01 to 2021-11-01
# extracting sur_refl_b16 data for 2021-11-01 to 2021-12-01
# Saved sur_refl_b16 data to pickle file

# %% [markdown]
# ### Merging Modis Data into a Common Dataframe

# %%
import os

modis_gb_all = pd.DataFrame()
modis_car_all = pd.DataFrame()

for file in os.listdir('./files/MODIS'):
    if file.startswith('modis_gb'):
        if modis_gb_all.shape[0] == 0:
            modis_gb_all = pd.read_pickle(f'./files/MODIS/{file}')
        else:
            modis_gb_all = modis_gb_all.merge(pd.read_pickle(f'./files/MODIS/{file}'), on=['longitude', 'latitude', 'time'], how='inner')   

    elif file.startswith('modis_car'):
        if modis_car_all.shape[0] == 0:
            modis_car_all = pd.read_pickle(f'./files/MODIS/{file}')
        else:
            modis_car_all = modis_car_all.merge(pd.read_pickle(f'./files/MODIS/{file}'), on=['longitude', 'latitude', 'time'], how='inner')
